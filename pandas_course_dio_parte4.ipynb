# %% [markdown]
# <a href="https://colab.research.google.com/github/kaiquefreire05/py-pandas-course/blob/main/pandas_course_dio_parte4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise Exploratória

# %%
# Importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn') # Mudando o estilo dos gráficos
# Out:
# <ipython-input-4-f1c2072973c9>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn') # Mudando o estilo dos gráficos

# %%
# Upload do arquivo
from google.colab import files
arq = files.upload()
# Out:
#      <input type="file" id="files-458e4d35-9ca0-42db-91b8-26716ebf3655" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-458e4d35-9ca0-42db-91b8-26716ebf3655">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Criando nosso DataFrame
df = pd.read_excel('AdventureWorks.xlsx')

# %%
# Visualizando 5 primeiras linhas
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
# Quantidade de linhas e colunas
df.shape
# Out:
# (904, 16)

# %%
# Verificando os tipos de dados
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
# Receita Total
df['Valor Venda'].sum()
# Out:
# 5984606.1426

# %%
# Criando a coluna Custo Total
df['Custo'] = df['Custo Unitário'].mul(df['Quantidade']) # Criando a coluna de custo
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor    Custo
# 0  Regular  Red  2091.48

# %%
# Soma do Custo Total
round(df['Custo'].sum(), 2) # Usando o round para printar apenas o valor em 2 casas decimais
# Out:
# 2486783.05

# %%
# Tenho o valor de venda e o custo do produto, então vou criar uma coluna para visualizar o lucro dos produtos
df['Lucro'] = df['Valor Venda'] - df['Custo']
df.head(2)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
# 1  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor    Custo    Lucro
# 0  Regular  Red  2091.48  2456.52
# 1  Regular  Red  2091.48  2456.52

# %%
# Total de lucro
round(df['Lucro'].sum(), 2)
# Out:
# 3497823.09

# %%
df['Tempo Envio'] = df['Data Envio'] - df['Data Venda']
df.head(2)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
# 1  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor    Custo    Lucro Tempo Envio
# 0  Regular  Red  2091.48  2456.52     20 days
# 1  Regular  Red  2091.48  2456.52      5 days

# %% [markdown]
# **Agora, quero saber o a médio do tempo de envio para cada marca, primeiro passo é transformar a coluna 'Tempo Envio' em numérica**

# %%
df['Tempo Envio'] = (df['Data Envio'] - df['Data Venda']).dt.days
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor    Custo    Lucro  Tempo Envio
# 0  Regular  Red  2091.48  2456.52           20

# %%
# Pegando a média de tempo de envio por 'Marca'
df.groupby('Marca')['Tempo Envio'].mean() # Fazendo um agrupamento por marca para saber a médio do tempo de envio
# Out:
# Marca
# Adventure Works    8.663866
# Contoso            8.470930
# Fabrikam           8.510121
# Name: Tempo Envio, dtype: float64

# %%
# Verificando se existe valores ausentes
df.isnull().sum() # Fazendo a soma dos valores ausentes no dataframe
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# Custo             0
# Lucro             0
# Tempo Envio       0
# dtype: int64

# %%
# Fazendo a conversão dos números da notação científica
pd.options.display.float_format = '{:20,.2f}'.format

# Fazendo agrupamento por Ano e Marca
df.groupby([df['Data Venda'].dt.year, 'Marca'])['Lucro'].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works             306,641.16
#             Contoso                      56,416.00
#             Fabrikam                  1,557,020.55
# 2009        Adventure Works             405,395.08
#             Contoso                     138,258.95
#             Fabrikam                  1,034,091.35
# Name: Lucro, dtype: float64

# %%
# Resetando o index
lucro_ano = df.groupby([df["Data Venda"].dt.year, 'Marca'])['Lucro'].sum().reset_index()
lucro_ano
# Out:
#    Data Venda            Marca                Lucro
# 0        2008  Adventure Works           306,641.16
# 1        2008          Contoso            56,416.00
# 2        2008         Fabrikam         1,557,020.55
# 3        2009  Adventure Works           405,395.08
# 4        2009          Contoso           138,258.95
# 5        2009         Fabrikam         1,034,091.35

# %%
# Total de produtos vendidos
df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=False)
# Out:
# Produto
# Headphone Adapter for Contoso Phone E130 Silver    25232
# Headphone Adapter for Contoso Phone E130 White     25008
# Adventure Works Laptop15.4W M1548 Black             1089
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey           1087
# Adventure Works Laptop15.4W M1548 Red               1047
# Fabrikam Trendsetter 2/3'' 17mm X100 Black           926
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black          884
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey           845
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White          789
# Name: Quantidade, dtype: int64

# %%
# Gráfico total de vendas por produto
df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=True).plot.barh(title='Total de produtos vendidos')
plt.xlabel('Total')
plt.ylabel('Produto')
# Out:
# Text(0, 0.5, 'Produto')

# %%
# Fazendo agrupamento por Ano e Marca
df.groupby(df['Data Venda'].dt.year)['Lucro'].sum().plot.bar(title='Lucro X Ano')
plt.xlabel('Ano')
plt.ylabel('Lucro')
# Out:
# Text(0, 0.5, 'Lucro')

# %%
# Selecionando apenas as vendas em 2009
df_2009 = df[df['Data Venda'].dt.year == 2009]
df_2009.head(2)
# Out:
#    Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 11 2009-05-02 2009-05-14      199         384       18938  200905023CS847
# 12 2009-05-16 2009-05-27      306         384       19067  200905163CS746
#
#          Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 11               348.58               758.00           6                 0.00
# 12               348.58               758.00           6                 0.00
#
#             Valor Venda                                Produto  \
# 11             4,548.00  Adventure Works Laptop15.4W M1548 Red
# 12             4,548.00  Adventure Works Laptop15.4W M1548 Red
#
#          Fabricante            Marca   Classe  Cor                Custo  \
# 11  Adventure Works  Adventure Works  Regular  Red             2,091.48
# 12  Adventure Works  Adventure Works  Regular  Red             2,091.48
#
#                   Lucro  Tempo Envio
# 11             2,456.52           12
# ...

# %%
# Pegando apenas o lucro por mês no ano de 2009
df_2009.groupby(df_2009['Data Venda'].dt.month)['Lucro'].sum().plot(title='Lucro X Mês')
plt.xlabel('Mês')
plt.ylabel('Lucro')
# Out:
# Text(0, 0.5, 'Lucro')

# %%
# Pegando apenas o lucro por marca no ano de 2009
df_2009.groupby('Marca')['Lucro'].sum().plot.bar(title='Lucro X Marca')
plt.xlabel('Marca')
plt.ylabel('Lucro')
plt.xticks(rotation='horizontal');

# %%
# Pegando apenas o lucro por classe no ano de 2009
df_2009.groupby('Classe')['Lucro'].sum().plot.bar(title='Lucro X Classe')
plt.xlabel('Marca')
plt.ylabel('Lucro')
plt.xticks(rotation='horizontal');

# %%
df['Tempo Envio'].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: Tempo Envio, dtype: float64

# %%
# Gráfico de Boxplot
plt.boxplot(df['Tempo Envio']);

# %%
# Histograma
plt.hist(df['Tempo Envio']);

# %%
df['Tempo Envio'].min()
# Out:
# 4

# %%
df['Tempo Envio'].max()
# Out:
# 20

# %%
# Identificando quem está sozinho de forma discrepante (Outlier)
df[df['Tempo Envio'] == 20]
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#         Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 0               348.58               758.00           6                 0.00
#
#            Valor Venda                                Produto  \
# 0             4,548.00  Adventure Works Laptop15.4W M1548 Red
#
#         Fabricante            Marca   Classe  Cor                Custo  \
# 0  Adventure Works  Adventure Works  Regular  Red             2,091.48
#
#                  Lucro  Tempo Envio
# 0             2,456.52           20

# %%
# Fazendo download
df.to_csv('df_vendas_novo.csv', index=False)
